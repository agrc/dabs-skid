# %%
import json
import logging
import sys
from datetime import datetime
from pathlib import Path
from tempfile import TemporaryDirectory
from types import SimpleNamespace

import arcgis
from palletjack import FeatureServiceInlineUpdater, GSheetLoader
from palletjack.transform import APIGeocoder
from supervisor.message_handlers import SendGridHandler
from supervisor.models import MessageDetails, Supervisor

try:
    from . import config, version
except ImportError:
    import config
    import version

cwd = Path.cwd()
print(cwd)
print(type(cwd))

secret_folder = cwd / "secrets"
secrets = json.loads((secret_folder / "secrets.json").read_text(encoding="utf-8"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17856\883084406.py in <cell line: 10>()
#       8
#       9 import arcgis
# ---> 10 from palletjack import (FeatureServiceInlineUpdater, GSheetLoader)
#      11 from palletjack.transform import APIGeocoder
#      12 from supervisor.message_handlers import SendGridHandler
#
# ModuleNotFoundError: No module named 'palletjack'

# %%
gis = arcgis.gis.GIS(config.AGOL_ORG, secrets["AGOL_USER"], secrets["AGOL_PASSWORD"])

feature_layer_item = gis.content.get(config.FEATURE_LAYER_ITEMID)
feature_layer = arcgis.features.FeatureLayer.fromitem(feature_layer_item)
featureset = feature_layer.query()
live_dataframe = featureset.sdf

# %%
live_dataframe.spatial.validate()
# Out:
# True

# %%
import pandas as pd

pd.options.mode.chained_assignment = None  # default='warn'

print("Reading in DABS data from Google Sheet ...")
loader = GSheetLoader(secrets["SERVICE_ACCOUNT_JSON"])
dabs_df = loader.load_specific_worksheet_into_dataframe(secrets["SHEET_ID"], "TEST_TAB", by_title=True)

#: Geocode rows if ACTION.casefold() == 'add'
print("Geocoding new rows ...")
adds_df = dabs_df[dabs_df["ACTION"].str.casefold() == "add"]
adds_df.drop(["ACTION"], axis="columns", inplace=True)
removes_df = dabs_df[dabs_df["ACTION"].str.casefold() == "remove"]

geocoder = APIGeocoder(secrets["GEOCODE_KEY"])
geo_df = geocoder.geocode_dataframe(adds_df, "Address", "Zip", 4326, rate_limits=(0.015, 0.03), acceptScore=90)
valid = geo_df.spatial.validate()
print(f"Is geo_df spatial?: {valid}")
# Out:
# Reading in DABS data from Google Sheet ...
# Geocoding new rows ...
# Is geo_df spatial?: True

# %%
live_dataframe.head(2)
# Out:
#    OBJECTID     County Suite_Unit Lic_Type Lic_Number  \
# 0         1  SALT LAKE       None       OP    OP00476
# 1         2      CACHE       None       OP    OP00594
#
#                    Lic_Descr                                Name  \
# 0  OFF PREMISE BEER RETAILER      WHOLE FOODS MARKET (SALT LAKE)
# 1  OFF PREMISE BEER RETAILER  TOP STOP CONVENIENCE STORE (LOGAN)
#
#                  Address            City    Zip Renew_Date    Lic_Group  \
# 0  1131 E WILMINGTON AVE  SALT LAKE CITY  84123       2/28  Off-Premise
# 1             970 N MAIN           LOGAN  84321       2/28  Off-Premise
#
#    Comp_Zone Comp_Group Comp_Needed     Point_X    Point_Y  \
# 0          4          F          no -111.858739  40.723633
# 1         10          A          no -111.834110  41.749773
#
#                                                SHAPE
# 0  {"spatialReference": {"wkid": 4326}, "x": -111...
# 1  {"spatialReference": {"wkid": 4326}, "x": -111...

# %%
geo_df.head(2)
# Out:
#   Lic_Number                    Name            Address        City    Zip  \
# 0    RL01498          CRUMB BROTHERS        291 S 300 W       LOGAN  84321
# 1    RL01499  SOCIAL DISTRICT BISTRO  250 RED CLIFFS DR  ST. GEORGE  84790
#
#             x          y  score                  matchAddress  \
# 0 -111.843346  41.726437  100.0            291 S 300 W, LOGAN
# 1 -113.553374  37.110635  100.0  250 RED CLIFFS DR, ST GEORGE
#
#                                                SHAPE
# 0  {"spatialReference": {"wkid": 4326}, "x": -111...
# 1  {"spatialReference": {"wkid": 4326}, "x": -113...

# %%
print(live_dataframe.iloc[0]["SHAPE"])
len(live_dataframe.index)
# Out:
# {'x': 427478.4543757879, 'y': 4508432.323816502, 'spatialReference': {'wkid': 102100, 'latestWkid': 3857}}
# 4296

# %%
pd.DataFrame.spatial.from_xy(df=live_dataframe, x_column="Point_X", y_column="Point_Y", sr=4326)
print(live_dataframe.iloc[0]["SHAPE"])
len(live_dataframe.index)
# Out:
# {'spatialReference': {'wkid': 4326}, 'x': -111.85873939, 'y': 40.7236328}
# 4296

# %%
print(geo_df.iloc[0]["SHAPE"])
len(geo_df.index)
# Out:
# {'spatialReference': {'wkid': 3857}, 'x': -12450344.320418216, 'y': 5120088.737326822}
# 17

# %%
working = live_dataframe.head(10)
working.head()

sref = arcgis.geometry.SpatialReference(3857)
# arcgis.geometry.project(geometries=working, in_sr=26912, out_sr=sref)

print(working.iloc[0]["SHAPE"])
print(working.iloc[0]["Point_X"])
print(working.iloc[0]["Point_Y"])
# Out:
# {'x': 427478.4543757879, 'y': 4508432.323816502, 'spatialReference': {'wkid': 102100, 'latestWkid': 3857}}
# -111.85873939
# 40.7236328

# %%
sref = arcgis.geometry.SpatialReference(3857)
arcgis.geometry.project(geometries=working["SHAPE"], in_sr=26912, out_sr=sref)

# sedf = pd.DataFrame.spatial.from_xy(df=live_dataframe, x_column='Point_X', y_column='Point_Y', sr=4326)
# sedf.iloc[0]['SHAPE']

# m = gis.map()
# m

print(reprojected.iloc[0]["SHAPE"])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In [83], line 2
#       1 sref = arcgis.geometry.SpatialReference(3857)
# ----> 2 arcgis.geometry.project(geometries=working['SHAPE'], in_sr=26912, out_sr=sref)
#       4 # sedf = pd.DataFrame.spatial.from_xy(df=live_dataframe, x_column='Point_X', y_column='Point_Y', sr=4326)
#       5 # sedf.iloc[0]['SHAPE']
#       6
#       7 # m = gis.map()
#       8 # m
#      10 print(reprojected.iloc[0]['SHAPE'])
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\site-packages\arcgis\geometry\functions.py:1095, in project(geometries, in_sr, out_sr, transformation, transform_forward, gis, future)
#    1093 if gis is None:
#    1094     gis = arcgis.env.active_gis
# -> 1095 return gis._tools.geometry.project(
#    1096     geometries, in_sr, out_sr, transformation, transform_forward, future=future
#    1097 )
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\site-packages\arcgis\_impl\tools.py:19962, in _GeometryService.project(self, geometries, inSR, outSR, transformation, transformFoward, future)
#   19960     return job
#   19961 else:
# > 19962     return job.result()
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\site-packages\arcgis\_impl\_async\jobs.py:158, in GeometryJob.result(self)
#     156 if self._wkid:  # set the output sr to that wkid integer
#     157     sr = {"spatialReference": {"wkid": self._wkid}}
# --> 158     res = self._future.result()
#     159     if isinstance(res, (list, tuple)):
#     161         [g.update(sr) for g in res if not "spatialReference" in g]
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\concurrent\futures\_base.py:446, in Future.result(self, timeout)
#     444     raise CancelledError()
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#     448     raise TimeoutError()
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\site-packages\arcgis\_impl\tools.py:18929, in _GeometryService._process_results(self, results, out_sr)
#   18926 from arcgis.geometry import SpatialReference
#   18928 if isinstance(results, concurrent.futures.Future):
# > 18929     results = results.result()
#   18930     if "error" in results:
#   18931         return results
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\concurrent\futures\_base.py:446, in Future.result(self, timeout)
#     444     raise CancelledError()
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#     448     raise TimeoutError()
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\site-packages\arcgis\gis\_impl\_con\_connection.py:1407, in Connection.post(self, path, params, files, **kwargs)
#    1405 if return_raw_response:
#    1406     return resp
# -> 1407 return self._handle_response(
#    1408     resp=resp,
#    1409     out_path=out_path,
#    1410     file_name=file_name,
#    1411     try_json=try_json,
#    1412     force_bytes=kwargs.pop("force_bytes", False),
#    1413 )
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\site-packages\arcgis\gis\_impl\_con\_connection.py:900, in Connection._handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     898             return data
#     899         errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 900         self._handle_json_error(data["error"], errorcode)
#     901     return data
#     902 else:
#
# File ~\AppData\Local\ESRI\conda\envs\dabs-skid\lib\site-packages\arcgis\gis\_impl\_con\_connection.py:923, in Connection._handle_json_error(self, error, errorcode)
#     920                 # _log.error(errordetail)
#     922 errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 923 raise Exception(errormessage)
#
# Exception: Invalid or missing input parameters.
# The operation was attempted on an empty geometry.
# null
# (Error Code: 400)

# %%
live_dataframe.spatial.validate()
# Out:
# True

# %%
combined = pd.concat([live_dataframe, geo_df])
combined.drop(["x", "y", "score", "matchAddress"], axis=1, inplace=True)

combined["Comp_Zone"].fillna(0, inplace=True)
combined["Comp_Zone"] = combined["Comp_Zone"].astype("int")

combined.tail(50)
# Out:
#       OBJECTID      County Suite_Unit Lic_Type Lic_Number           Lic_Descr  \
# 4263      4271       CACHE       None       RL    RL00371  RESTAURANT LIMITED
# 4264      4272       EMERY       None       RL    RL00863  RESTAURANT LIMITED
# 4265      4273        UTAH       None       RL    RL01339  RESTAURANT LIMITED
# 4266      4274   SALT LAKE       None       RL    RL00444  RESTAURANT LIMITED
# 4267      4275        UTAH       None       RL    RL01331  RESTAURANT LIMITED
# 4268      4276       CACHE       None       RL    RL00537  RESTAURANT LIMITED
# 4269      4277        UTAH       None       RL    RL01324  RESTAURANT LIMITED
# 4270      4278   SALT LAKE       None       RL    RL01377  RESTAURANT LIMITED
# 4271      4279       DAVIS       None       RL    RL00880  RESTAURANT LIMITED
# 4272      4280       DAVIS       None       RL    RL00910  RESTAURANT LIMITED
# 4273      4281      SUMMIT       None       RL    RL01394  RESTAURANT LIMITED
# 4274      4282   SALT LAKE       None       RL    RL01311  RESTAURANT LIMITED
# 4275      4283       DAVIS       None       RL    RL00056  RESTAURANT LIMITED
# 4276      4284        UTAH       None       RL    RL00296  RESTAURANT LIMITED
# 4277      4285        UTAH       None       RL    RL01163  RESTAURANT LIMITED
# 4278      4286   SALT LAKE       None       RL    RL00227  RESTAURANT LIMITED
# 4279      4287   SALT LAKE       None       RL    RL00018  RESTAURANT LIMITED
# 4280      4288       GRAND       None       RL    RL01256  RESTAURANT LIMITED
# 4281      4289   SALT LAKE       None       RL    RL01237  RESTAURANT LIMITED
# 4282      4290      TOOELE       None       RL    RL00990  RESTAURANT LIMITED
# 4283      4291  WASHINGTON       None       RL    RL00322  RESTAURANT LIMITED
# 4284      4292  WASHINGTON       None       RL    RL00242  RESTAURANT LIMITED
# 4285      4293        KANE       None       RL    RL00545  RESTAURANT LIMITED
# 4286      4294        KANE       None       RL    RL01464  RESTAURANT LIMITED
# 4287      4295        IRON       None       RL    RL01439  RESTAURANT LIMITED
# 4288      4296       DAVIS       None       RL    RL00930  RESTAURANT LIMITED
# 4289      4297   SALT LAKE       None       RL    RL00603  RESTAURANT LIMITED
# 4290      4298      SUMMIT       None       RL    RL01293  RESTAURANT LIMITED
# 4291      4299       WAYNE       None       RL    RL01137  RESTAURANT LIMITED
# 4292      4300   SALT LAKE       None       RL    RL01083  RESTAURANT LIMITED
# 4293      4301  WASHINGTON       None       RL    RL01406  RESTAURANT LIMITED
# 4294      4302   SALT LAKE       None       RL    RL00876  RESTAURANT LIMITED
# 4295      4303       WEBER       None       RL    RL00893  RESTAURANT LIMITED
# 0         4304         NaN        NaN      NaN    RL01498                 NaN
# 1         4305         NaN        NaN      NaN    RL01499                 NaN
# 2         4306         NaN        NaN      NaN    RE03053                 NaN
# 3         4307         NaN        NaN      NaN    BE02740                 NaN
# 4         4308         NaN        NaN      NaN    RE03057                 NaN
# 5         4309         NaN        NaN      NaN    RE03054                 NaN
# 6         4310         NaN        NaN      NaN    HL00052                 NaN
# 7         4311         NaN        NaN      NaN    RE03055                 NaN
# 8         4312         NaN        NaN      NaN    MR00225                 NaN
# 9         4313         NaN        NaN      NaN    MW00040                 NaN
# 10        4314         NaN        NaN      NaN    PS00053                 NaN
# 11        4315         NaN        NaN      NaN    RE03052                 NaN
# 12        4316         NaN        NaN      NaN    OP01988                 NaN
# 13        4317         NaN        NaN      NaN   OP101989                 NaN
# 14        4318         NaN        NaN      NaN   OP101993                 NaN
# 15        4319         NaN        NaN      NaN    OP01992                 NaN
# 16        4320         NaN        NaN      NaN    PA00479                 NaN
#
#                                   Name                               Address  \
# 4263  TAKARA SUSHI JAPANESE RESTAURANT                       55 W 1000 N  #1
# 4264               TAMARISK RESTAURANT                        1710 E MAIN ST
# 4265         TAMASHI RAMEN & SUSHI BAR                           466 N 900 W
# 4266                           TANDOOR                          733 E 3300 S
# 4267      TANDOOR INDIAN GRILL (PROVO)                   1600 N FREEDOM BLVD
# 4268                     TANDOORI OVEN                          720 E 1000 N
# 4269       TAPA SUSHI JAPANESE CUISINE                     513 S 500 E STE A
# 4270                        TAPPO (RL)                          565 E 2100 S
# 4271                    TASTE OF INDIA    1664 WOODLAND PARK DR STE 401  401
# 4272              TASTE OF INDIA GRILL                     282 S 500 W STE A
# 4273                TASTE OF THAI (RL)                   1241 CENTER DR L160
# 4274                        TEA ZAANTI                         1944 S 1100 E
# 4275                         TEPANYAKI                 1386 S LEGEND HILL DR
# 4276                  TEPANYAKI (LEHI)                            72 N 850 E
# 4277                  TEPANYAKI (OREM)              777 E UNIVERSITY PARKWAY
# 4278           TEPANYAKI (WEST JORDAN)                 7233 S PLAZA CTR DR -
# 4279                        TERU SUSHI                1844 E 7000 S UNIT  #3
# 4280                        THAI BELLA                     218 N 100 W - - -
# 4281           THAI GARDEN BISTRO (RL)                           868 E 900 S
# 4282             THAI HOUSE RESTAURANT                            297 N MAIN
# 4283                THAI PLACE & SUSHI  2 W ST GEORGE BLVD (ANCESTOR SQUAR -
# 4284                         THAI SAPA                    198 ZION PARK BLVD
# 4285                 THE BUFFALO GRILL                          9065 W HWY 9
# 4286                          THE DELI                  815 E MOVIE RANCH RD
# 4287                   THE FRENCH SPOT                      20 S MAIN STREET
# 4288                   THE LUCKY SLICE               1246 S LEGEND HILLS DR
# 4289                           THE MED                    420 E 3300 SOUTH -
# 4290                         THE NOTCH                2392 E MIRROR LAKE HWY
# 4291                      THE SADDLERY                            450 W MAIN
# 4292              THE SUSHI RESTAURANT                 684 E 11400 S STE G -
# 4293  TIAS ARTISAN BAKERY & RESTAURANT                    1812 W SUNSET BLVD
# 4294          TIO'S MEXICAN RESTAURANT                    4709 DAYBREAK PKWY
# 4295                     TOKYO STATION                2259 S WASHINGTON BLVD
# 0                       CRUMB BROTHERS                           291 S 300 W
# 1               SOCIAL DISTRICT BISTRO                     250 RED CLIFFS DR
# 2          MR & MRS CRAB JUICY SEAFOOD                     4150 S REDWOOD RD
# 3                   BLUES AT THE DEPOT                            13 N 400 W
# 4                      HEIRLOOM COMMON                         195 W MAIN ST
# 5                        MEAT HOOK BBQ                     3380 S REDWOOD RD
# 6             AC MARRIOTT SLC DOWNTOWN                           225 W 200 S
# 7                              TOPGOLF                           484 N 700 E
# 8                         SCOTT RICHEY            14301 N COUNCIL FIRE TRAIL
# 9            EVERYTHING GOOD NURTITION                         1630 S 4650 W
# 10                       ALLEGIANT AIR                  3421 MIKE JENSE PKWY
# 11            AQUA TERRA STEAK & SUSHI                            50 S. MAIN
# 12                      RANCHO MARKETS                    580 S STATE STREET
# 13                     HOLIDAY OIL #73                         1318 N 2000 W
# 14              COSTCO WHOLESALE #1633                         1160 N 1000 W
# 15                        EXPRESS MART                           15 S HWY 89
# 16    THE MARKET @ HYATT REGENCY HOTEL                     170 S WEST TEMPLE
#
#                     City         Zip Renew_Date   Lic_Group  Comp_Zone  \
# 4263               LOGAN       84321      10/31  Restaurant         10
# 4264         GREEN RIVER       84525      10/31  Restaurant         14
# 4265       AMERICAN FORK       84003      10/31  Restaurant         12
# 4266      SALT LAKE CITY       84106      10/31  Restaurant          7
# 4267               PROVO       84604      10/31  Restaurant         15
# 4268               LOGAN       84321      10/31  Restaurant         10
# 4269       AMERICAN FORK       84003      10/31  Restaurant         12
# 4270      SALT LAKE CITY       84106      10/31  Restaurant          4
# 4271              LAYTON       84041      10/31  Restaurant         11
# 4272           BOUNTIFUL       84010      10/31  Restaurant          3
# 4273           PARK CITY       84098      10/31  Restaurant          8
# 4274      SALT LAKE CITY       84106      10/31  Restaurant          4
# 4275          CLEARFIELD  84015-1585      10/31  Restaurant         11
# 4276                LEHI  84043-9576      10/31  Restaurant         12
# 4277                OREM       84097      10/31  Restaurant         15
# 4278         WEST JORDAN       84084      10/31  Restaurant          6
# 4279      SALT LAKE CITY       84121      10/31  Restaurant          6
# 4280                MOAB       84532      10/31  Restaurant         14
# 4281      SALT LAKE CITY       84101      10/31  Restaurant          4
# 4282              TOOELE       84074      10/31  Restaurant          5
# 4283           ST GEORGE       84770      10/31  Restaurant         17
# 4284          SPRINGDALE       84767      10/31  Restaurant         17
# 4285        MOUNT CARMEL       84755      10/31  Restaurant         17
# 4286  DUCK CREEK VILLAGE       84762      10/31  Restaurant         17
# 4287          CEDAR CITY       84720      10/31  Restaurant         17
# 4288          CLEARFIELD  84015-2273      10/31  Restaurant         11
# 4289      SALT LAKE CITY       84115      10/31  Restaurant          7
# 4290               KAMAS       84036      10/31  Restaurant         12
# 4291              TORREY       84775      10/31  Restaurant         16
# 4292              DRAPER       84020      10/31  Restaurant          9
# 4293        SAINT GEORGE       84770      10/31  Restaurant         17
# 4294        SOUTH JORDAN       84095      10/31  Restaurant          6
# 4295               OGDEN       84401      10/31  Restaurant         10
# 0                  LOGAN       84321        NaN         NaN          0
# 1             ST. GEORGE       84790        NaN         NaN          0
# 2                    SLC       84123        NaN         NaN          0
# 3                    SLC       84101        NaN         NaN          0
# 4                 MIDWAY       84049        NaN         NaN          0
# 5                    SLC       84119        NaN         NaN          0
# 6                    SLC       84101        NaN         NaN          0
# 7               VINEYARD       84057        NaN         NaN          0
# 8                  KAMAS       84036        NaN         NaN          0
# 9                    SLC       84104        NaN         NaN          0
# 10                 PROVO       84601        NaN         NaN          0
# 11        SALT LAKE CITY       84101        NaN         NaN          0
# 12            CLEARFIELD       84015        NaN         NaN          0
# 13            CLEARFIELD       84015        NaN         NaN          0
# 14                 LOGAN       84321        NaN         NaN          0
# 15       NORTH SALT LAKE       84054        NaN         NaN          0
# 16        SALT LAKE CITY       84104        NaN         NaN          0
#
#      Comp_Group Comp_Needed     Point_X    Point_Y  \
# 4263          A         yes -111.836177  41.750526
# 4264          F         yes -110.141991  38.993144
# 4265          D         yes -111.820271  40.387060
# 4266          E         yes -111.870108  40.700310
# 4267          E         yes -111.661717  40.255809
# 4268          A         yes -111.816054  41.749754
# 4269          D         yes -111.784851  40.366678
# 4270          F         yes -111.874791  40.725641
# 4271          B         yes -111.984083  41.084552
# 4272          B         yes -111.892411  40.886494
# 4273          C         yes -111.539061  40.721375
# 4274          F         yes -111.859949  40.727949
# 4275          B         yes -111.994631  41.094770
# 4276          D         yes -111.834894  40.388773
# 4277          E         yes -111.677159  40.273296
# 4278          G         yes -111.978972  40.619791
# 4279          G         yes -111.941474  40.624181
# 4280          F         yes -109.552396  38.576700
# 4281          F         yes -111.866285  40.749515
# 4282          A         yes -112.299534  40.536037
# 4283     Solo 3         yes -113.584304  37.110250
# 4284     Solo 3         yes -112.991746  37.198104
# 4285     Solo 3         yes -112.839709  37.238124
# 4286     Solo 3         yes -112.665544  37.524938
# 4287     Solo 3         yes -113.061914  37.677005
# 4288          B         yes -111.996144  41.096258
# 4289          E         yes -111.879609  40.699614
# 4290          D         yes -111.234613  40.625156
# 4291          G         yes -111.430724  38.299610
# 4292          D         yes -111.872327  40.543680
# 4293     Solo 3         yes -113.622454  37.123134
# 4294          G         yes -112.003100  40.546964
# 4295          A         yes -111.970707  41.225824
# 0           NaN         NaN         NaN        NaN
# 1           NaN         NaN         NaN        NaN
# 2           NaN         NaN         NaN        NaN
# 3           NaN         NaN         NaN        NaN
# 4           NaN         NaN         NaN        NaN
# 5           NaN         NaN         NaN        NaN
# 6           NaN         NaN         NaN        NaN
# 7           NaN         NaN         NaN        NaN
# 8           NaN         NaN         NaN        NaN
# 9           NaN         NaN         NaN        NaN
# 10          NaN         NaN         NaN        NaN
# 11          NaN         NaN         NaN        NaN
# 12          NaN         NaN         NaN        NaN
# 13          NaN         NaN         NaN        NaN
# 14          NaN         NaN         NaN        NaN
# 15          NaN         NaN         NaN        NaN
# 16          NaN         NaN         NaN        NaN
#
#                                                   SHAPE
# 4263  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4264  {"spatialReference": {"wkid": 4326}, "x": -110...
# 4265  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4266  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4267  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4268  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4269  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4270  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4271  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4272  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4273  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4274  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4275  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4276  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4277  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4278  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4279  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4280  {"spatialReference": {"wkid": 4326}, "x": -109...
# 4281  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4282  {"spatialReference": {"wkid": 4326}, "x": -112...
# 4283  {"spatialReference": {"wkid": 4326}, "x": -113...
# 4284  {"spatialReference": {"wkid": 4326}, "x": -112...
# 4285  {"spatialReference": {"wkid": 4326}, "x": -112...
# 4286  {"spatialReference": {"wkid": 4326}, "x": -112...
# 4287  {"spatialReference": {"wkid": 4326}, "x": -113...
# 4288  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4289  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4290  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4291  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4292  {"spatialReference": {"wkid": 4326}, "x": -111...
# 4293  {"spatialReference": {"wkid": 4326}, "x": -113...
# 4294  {"spatialReference": {"wkid": 4326}, "x": -112...
# 4295  {"spatialReference": {"wkid": 4326}, "x": -111...
# 0     {"spatialReference": {"wkid": 4326}, "x": -111...
# 1     {"spatialReference": {"wkid": 4326}, "x": -113...
# 2     {"spatialReference": {"wkid": 4326}, "x": -111...
# 3     {"spatialReference": {"wkid": 4326}, "x": -111...
# 4     {"spatialReference": {"wkid": 4326}, "x": -111...
# 5     {"spatialReference": {"wkid": 4326}, "x": -111...
# 6     {"spatialReference": {"wkid": 4326}, "x": -111...
# 7     {"spatialReference": {"wkid": 4326}, "x": -111...
# 8     {"spatialReference": {"wkid": 4326}, "x": -111...
# 9     {"spatialReference": {"wkid": 4326}, "x": -112...
# 10    {"spatialReference": {"wkid": 4326}, "x": -111...
# 11    {"spatialReference": {"wkid": 4326}, "x": -111...
# 12    {"spatialReference": {"wkid": 4326}, "x": -112...
# 13    {"spatialReference": {"wkid": 4326}, "x": -112...
# 14    {"spatialReference": {"wkid": 4326}, "x": -111...
# 15    {"spatialReference": {"wkid": 4326}, "x": -111...
# 16    {"spatialReference": {"wkid": 4326}, "x": -111...

# %%
print(combined["OBJECTID"].max())
# Out:
# 4303.0

# %%
# live_dataframe = live_dataframe.astype({"OBJECTID": int})
# geo_df['OBJECTID'] = 0
max_OID = live_dataframe["OBJECTID"].max()

print(max_OID)

geo_df.insert(0, "OBJECTID", range(max_OID + 1, max_OID + len(geo_df) + 1))

len(geo_df.index)
geo_df.head(20)
# Out:
# 4303
#     OBJECTID Lic_Number                              Name  \
# 0       4304    RL01498                    CRUMB BROTHERS
# 1       4305    RL01499            SOCIAL DISTRICT BISTRO
# 2       4306    RE03053       MR & MRS CRAB JUICY SEAFOOD
# 3       4307    BE02740                BLUES AT THE DEPOT
# 4       4308    RE03057                   HEIRLOOM COMMON
# 5       4309    RE03054                     MEAT HOOK BBQ
# 6       4310    HL00052          AC MARRIOTT SLC DOWNTOWN
# 7       4311    RE03055                           TOPGOLF
# 8       4312    MR00225                      SCOTT RICHEY
# 9       4313    MW00040         EVERYTHING GOOD NURTITION
# 10      4314    PS00053                     ALLEGIANT AIR
# 11      4315    RE03052          AQUA TERRA STEAK & SUSHI
# 12      4316    OP01988                    RANCHO MARKETS
# 13      4317   OP101989                   HOLIDAY OIL #73
# 14      4318   OP101993            COSTCO WHOLESALE #1633
# 15      4319    OP01992                      EXPRESS MART
# 16      4320    PA00479  THE MARKET @ HYATT REGENCY HOTEL
#
#                        Address             City    Zip           x          y  \
# 0                  291 S 300 W            LOGAN  84321 -111.843346  41.726437
# 1            250 RED CLIFFS DR       ST. GEORGE  84790 -113.553374  37.110635
# 2            4150 S REDWOOD RD              SLC  84123 -111.939222  40.680960
# 3                   13 N 400 W              SLC  84101 -111.902971  40.769724
# 4                195 W MAIN ST           MIDWAY  84049 -111.476412  40.512102
# 5            3380 S REDWOOD RD              SLC  84119 -111.939269  40.698975
# 6                  225 W 200 S              SLC  84101 -111.897695  40.764778
# 7                  484 N 700 E         VINEYARD  84057 -111.678873  40.306057
# 8   14301 N COUNCIL FIRE TRAIL            KAMAS  84036 -111.431921  40.681506
# 9                1630 S 4650 W              SLC  84104 -112.003048  40.735193
# 10        3421 MIKE JENSE PKWY            PROVO  84601 -111.718519  40.219319
# 11                  50 S. MAIN   SALT LAKE CITY  84101 -111.891652  40.767870
# 12          580 S STATE STREET       CLEARFIELD  84015 -112.018175  41.104875
# 13               1318 N 2000 W       CLEARFIELD  84015 -112.064089  41.133197
# 14               1160 N 1000 W            LOGAN  84321 -111.858116  41.753059
# 15                 15 S HWY 89  NORTH SALT LAKE  84054 -111.910296  40.841458
# 16           170 S WEST TEMPLE   SALT LAKE CITY  84104 -111.894597  40.765667
#
#      score                          matchAddress  \
# 0   100.00                    291 S 300 W, LOGAN
# 1   100.00          250 RED CLIFFS DR, ST GEORGE
# 2   100.00     4150 S REDWOOD RD, SALT LAKE CITY
# 3   100.00            13 N 400 W, SALT LAKE CITY
# 4   100.00                 195 W MAIN ST, Midway
# 5   100.00     3380 S REDWOOD RD, SALT LAKE CITY
# 6   100.00           225 W 200 S, SALT LAKE CITY
# 7   100.00                     484 N 700 E, Orem
# 8   100.00  14301 N COUNCIL FIRE TRL, HEBER CITY
# 9   100.00         1630 S 4650 W, SALT LAKE CITY
# 10  100.00           3421 MIKE JENSE PKWY, PROVO
# 11   90.92          50 S MAIN ST, SALT LAKE CITY
# 12  100.00            580 S STATE ST, CLEARFIELD
# 13  100.00             1318 N 2000 W, CLEARFIELD
# 14  100.00                  1160 N 1000 W, LOGAN
# 15  100.00                  15 S HIGHWAY 89, Nsl
# 16   90.92  170 S WEST TEMPLE ST, SALT LAKE CITY
#
#                                                 SHAPE
# 0   {"spatialReference": {"wkid": 4326}, "x": -111...
# 1   {"spatialReference": {"wkid": 4326}, "x": -113...
# 2   {"spatialReference": {"wkid": 4326}, "x": -111...
# 3   {"spatialReference": {"wkid": 4326}, "x": -111...
# 4   {"spatialReference": {"wkid": 4326}, "x": -111...
# 5   {"spatialReference": {"wkid": 4326}, "x": -111...
# 6   {"spatialReference": {"wkid": 4326}, "x": -111...
# 7   {"spatialReference": {"wkid": 4326}, "x": -111...
# 8   {"spatialReference": {"wkid": 4326}, "x": -111...
# 9   {"spatialReference": {"wkid": 4326}, "x": -112...
# 10  {"spatialReference": {"wkid": 4326}, "x": -111...
# 11  {"spatialReference": {"wkid": 4326}, "x": -111...
# 12  {"spatialReference": {"wkid": 4326}, "x": -112...
# 13  {"spatialReference": {"wkid": 4326}, "x": -112...
# 14  {"spatialReference": {"wkid": 4326}, "x": -111...
# 15  {"spatialReference": {"wkid": 4326}, "x": -111...
# 16  {"spatialReference": {"wkid": 4326}, "x": -111...

# %%
# geo_df.drop('OBJECTID', axis=1, inplace=True)

# %%
type(geo_df.iloc[1].OBJECTID)
# Out:
# numpy.int64

# %%
import time

month_tab = time.strftime("%m/%Y")
print(month_tab)
# Out:
# 10/2022

# %%
str_date_added = time.strftime("%Y%m%d")
print(str_date_added)
# Out:
# 20221005
